# %% [markdown]
# <a href="https://colab.research.google.com/github/Srujanapesala/VEDIO_GAME-/blob/main/srujana_mini_vediogame_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("Video_Games1.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df['Critic_Score']
# Out:
# 0        76.0
# 1         NaN
# 2        82.0
# 3        80.0
# 4         NaN
#          ...
# 16714     NaN
# 16715     NaN
# 16716     NaN
# 16717     NaN
# 16718     NaN
# Name: Critic_Score, Length: 16719, dtype: float64

# %%
# Fill missing values for categorical columns using mode
categorical_columns = ['Name', 'Genre', 'Publisher', 'Developer', 'Rating']
for col in categorical_columns:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# C:\Users\Tarun\AppData\Local\Temp\ipykernel_16224\2930464175.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release     269
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer             0
# Rating                0
# dtype: int64

# %%
#user_score column contain tbd values
df[df['User_Score'] == 'tbd']
# Out:
#                                            Name Platform  Year_of_Release  \
# 119                               Zumba Fitness      Wii           2010.0
# 301              Namco Museum: 50th Anniversary      PS2           2005.0
# 520                             Zumba Fitness 2      Wii           2011.0
# 645                                uDraw Studio      Wii           2010.0
# 657    Frogger's Adventures: Temple of the Frog      GBA              NaN
# ...                                         ...      ...              ...
# 16699                           Planet Monsters      GBA           2001.0
# 16701                          Bust-A-Move 3000       GC           2003.0
# 16702                          Mega Brain Boost       DS           2008.0
# 16708                                  Plushees       DS           2008.0
# 16710             Men in Black II: Alien Escape       GC           2003.0
#
#             Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#replace tbd values with NA and converted the datatype of user_score
df['User_Score'].replace('tbd', pd.NA, inplace=True)
df['User_Score'] = pd.to_numeric(df['User_Score'])
# Out:
# C:\Users\Tarun\AppData\Local\Temp\ipykernel_16224\3131218167.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['User_Score'].replace('tbd', pd.NA, inplace=True)

# %%
# Fill missing values for numerical columns
numerical_columns_mean = ['Critic_Score', 'User_Score']
for col in numerical_columns_mean:
    df[col].fillna(df[col].mean(), inplace=True)
# Out:
# C:\Users\Tarun\AppData\Local\Temp\ipykernel_16224\2272617087.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
# Fill missing values for numerical columns
numerical_columns_median = ['Year_of_Release', 'Critic_Count', 'User_Count']
for col in numerical_columns_median:
    df[col].fillna(df[col].median(), inplace=True)
# Out:
# C:\Users\Tarun\AppData\Local\Temp\ipykernel_16224\2287663909.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\Tarun\AppData\Local\Temp\ipykernel_16224\2287663909.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53     76.000000
# 1     29.08      3.58      6.81         0.77         40.24     68.967679
# 2     15.68     12.76      3.79         3.29         35.52     82.000000
# 3     15.61     10.93      3.28         2.95         32.77     80.000000
# 4     11.27      8.89     10.22         1.00         31.37     68.967679
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df.to_csv("Video_Games_Cleaned.csv", index=False)

# %%
#1. Get sample of 5 rows
df.sample(5)
# Out:
#                                          Name Platform  Year_of_Release  \
# 6782                           Panzer General       PS           1995.0
# 15142                                 Demigod       PC           2009.0
# 11406  Pretty Rhythm: My Deco Rainbow Wedding      3DS           2013.0
# 6331                               Shadow Man      N64           1999.0
# 2342     Tiger Woods PGA Tour 12: The Masters      PS3           2011.0
#
#           Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 6782   Strategy              Mindscape      0.14      0.09      0.00
# 15142  Strategy                  Atari      0.00      0.02      0.00
# 11406      Misc            Takara Tomy      0.00      0.00      0.08
# 6331     Action  Acclaim Entertainment      0.18      0.08      0.00
# 2342     Sports        Electronic Arts      0.52      0.25      0.00
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# ...

# %%
#2.2. Display all the columns
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
#3.Display the dimensions
df.shape
# Out:
# (16719, 16)

# %%
#4. Dispaly all columns data types
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
#5. Display Top 10 rows
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
#6.Bottom 10 rows
df.tail(10)
# Out:
#                                                    Name Platform  \
# 16709                                           15 Days       PC
# 16710                     Men in Black II: Alien Escape       GC
# 16711                                  Aiyoku no Eustia      PSV
# 16712                Woody Woodpecker in Crazy Castle 5      GBA
# 16713  SCORE International Baja 1000: The Official Game      PS2
# 16714                     Samurai Warriors: Sanada Maru      PS3
# 16715                                  LMA Manager 2007     X360
# 16716                           Haitaka no Psychedelica      PSV
# 16717                                  Spirits & Spells      GBA
# 16718                               Winning Post 8 2016      PSV
#
#        Year_of_Release       Genre          Publisher  NA_Sales  EU_Sales  \
# 16709           2009.0   Adventure  DTP Entertainment      0.00      0.01
# 16710           2003.0     Shooter         Infogrames      0.01      0.00
# ...

# %%
#7.Display all Racing Games which have Critic_score >= 95.
dfrg = df[(df['Genre'] == 'Racing') & (df['Critic_Score'] >= 95)]
dfrg
# Out:
#                       Name Platform  Year_of_Release   Genre  \
# 28  Gran Turismo 3: A-Spec      PS2           2001.0  Racing
# 52            Gran Turismo       PS           1997.0  Racing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 28  Sony Computer Entertainment      6.85      5.09      1.87         1.16
# 52  Sony Computer Entertainment      4.02      3.87      2.54         0.52
#
#     Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# 28         14.98          95.0          54.0         8.4       314.0
# 52         10.95          96.0          16.0         8.7       138.0
#
#             Developer Rating
# 28  Polyphony Digital      E
# 52  Polyphony Digital      E

# %%
#8.Display video games whos user_score>9.
dfvg = df[df['User_Score'] > 9]
dfvg
# Out:
#                                             Name Platform  Year_of_Release  \
# 65                             Final Fantasy VII       PS           1997.0
# 97                          Super Mario Galaxy 2      Wii           2010.0
# 106                                     Tekken 3       PS           1998.0
# 110                                 Mario Kart 8     WiiU           2014.0
# 111                      Super Smash Bros. Melee       GC           2001.0
# ...                                          ...      ...              ...
# 16230                  Monster Rancher Advance 2      GBA           2002.0
# 16355                                    Deus Ex       PC           2000.0
# 16433  Greg Hastings' Tournament Paintball Max'd      PS2           2006.0
# 16550                Wade Hixton's Counter Punch      GBA           2004.0
# 16631                              Karnaaj Rally      GBA           2003.0
#
# ...

# %%
#9.Display all unique user_scores
dfus = df['User_Score'].unique()
dfus
# Out:
# array([8.        , 7.12504611, 8.3       , 8.5       , 6.6       ,
#        8.4       , 8.6       , 7.7       , 6.3       , 7.4       ,
#        8.2       , 9.        , 7.9       , 8.1       , 8.7       ,
#        7.1       , 3.4       , 5.3       , 4.8       , 3.2       ,
#        8.9       , 6.4       , 7.8       , 7.5       , 2.6       ,
#        7.2       , 9.2       , 7.        , 7.3       , 4.3       ,
#        7.6       , 5.7       , 5.        , 9.1       , 6.5       ,
#        8.8       , 6.9       , 9.4       , 6.8       , 6.1       ,
#        6.7       , 5.4       , 4.        , 4.9       , 4.5       ,
#        9.3       , 6.2       , 4.2       , 6.        , 3.7       ,
#        4.1       , 5.8       , 5.6       , 5.5       , 4.4       ,
#        4.6       , 5.9       , 3.9       , 3.1       , 2.9       ,
#        5.2       , 3.3       , 4.7       , 5.1       , 3.5       ,
#        2.5       , 1.9       , 3.        , 2.7       , 2.2       ,
# ...

# %%
#10.Display all types of Games
dftg = df['Genre'].unique()
dftg
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
#11. Access row 15
df.iloc[14]
# Out:
# Name                   Kinect Adventures!
# Platform                             X360
# Year_of_Release                    2010.0
# Genre                                Misc
# Publisher          Microsoft Game Studios
# NA_Sales                             30.0
# EU_Sales                             4.89
# JP_Sales                             0.24
# Other_Sales                          1.69
# Global_Sales                        21.81
# Critic_Score                         61.0
# Critic_Count                         45.0
# User_Score                            6.3
# User_Count                          106.0
# Developer             Good Science Studio
# Rating                                  E
# Name: 14, dtype: object

# %%
#12.Display EU_Sales,Global_Sales and Critic_Count of all games using iloc
df.iloc[:, [df.columns.get_loc('EU_Sales'), df.columns.get_loc('Global_Sales'), df.columns.get_loc('Critic_Count')]]
# Out:
#        EU_Sales  Global_Sales  Critic_Count
# 0         28.96         82.53          51.0
# 1          3.58         40.24          21.0
# 2         12.76         35.52          73.0
# 3         10.93         32.77          73.0
# 4          8.89         31.37          21.0
# ...         ...           ...           ...
# 16714      0.00          0.01          21.0
# 16715      0.01          0.01          21.0
# 16716      0.00          0.01          21.0
# 16717      0.00          0.01          21.0
# 16718      0.00          0.01          21.0
#
# [16719 rows x 3 columns]

# %%
#13.Display the Name, Genre, and Developer of all games using loc
df.loc[:, ['Name', 'Genre', 'Developer']]
# Out:
#                                 Name         Genre Developer
# 0                         Wii Sports        Sports  Nintendo
# 1                  Super Mario Bros.      Platform   Ubisoft
# 2                     Mario Kart Wii        Racing  Nintendo
# 3                  Wii Sports Resort        Sports  Nintendo
# 4           Pokemon Red/Pokemon Blue  Role-Playing   Ubisoft
# ...                              ...           ...       ...
# 16714  Samurai Warriors: Sanada Maru        Action   Ubisoft
# 16715               LMA Manager 2007        Sports   Ubisoft
# 16716        Haitaka no Psychedelica     Adventure   Ubisoft
# 16717               Spirits & Spells      Platform   Ubisoft
# 16718            Winning Post 8 2016    Simulation   Ubisoft
#
# [16719 rows x 3 columns]

# %%
#14.Change User_Score data type to float and display all columns data types
df['User_Score'] = pd.to_numeric(df['User_Score'])

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
#15.Which developer has made how much sales in USD gloabally
df.groupby('Developer')['Global_Sales'].sum().sort_values(ascending = False)
# Out:
# Developer
# Ubisoft                                2962.00
# Nintendo                                531.71
# EA Sports                               175.38
# EA Canada                               142.32
# Rockstar North                          119.47
#                                         ...
# Black Bean Games                          0.01
# Bigben Interactive, Red Wagon Games       0.01
# 777 Studios                               0.01
# 1C, Various, 1C Company                   0.01
# React Games                               0.01
# Name: Global_Sales, Length: 1696, dtype: float64

# %%
#16.Remove all null values from User_Score
dfnv = df.dropna(subset = ['User_Score'])
dfnv
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
#17.Plot the histogram chart with x=User_Score and y=Developer
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
df['User_Score'].hist(bins=20)
plt.xlabel('User Score')
plt.ylabel('Count')
plt.title('Distribution of User Scores')
plt.show()

# %%
#18.Display all video games.
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
#19.Update NA_Sales with + 5:
df['NA_Sales'] = df['NA_Sales'].map(lambda x: x + 5)
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
#20.Display which Genre has how many games
all_games = df.groupby('Genre').Genre.count()
all_games
# Out:
# Genre
# Action          3372
# Adventure       1303
# Fighting         849
# Misc            1750
# Platform         888
# Puzzle           580
# Racing          1249
# Role-Playing    1500
# Shooter         1323
# Simulation       874
# Sports          2348
# Strategy         683
# Name: Genre, dtype: int64

# %%
#21.Create a bar chart for all games
plt.figure(figsize=(5,5))
all_games.plot(kind='bar', color='skyblue')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Number of Games per Genre')
plt.xticks(rotation=60)
plt.show()

# %%
#22. Which developer has most games sold:
top_developers = df.groupby('Developer')['Global_Sales'].sum().sort_values(ascending=False).head(20)
top_developers
# Out:
# Developer
# Ubisoft                    2962.00
# Nintendo                    531.71
# EA Sports                   175.38
# EA Canada                   142.32
# Rockstar North              119.47
# Capcom                      115.71
# Ubisoft Montreal            108.31
# Treyarch                    103.16
# EA Tiburon                   96.12
# Traveller's Tales            79.22
# Infinity Ward                77.62
# Visual Concepts              72.87
# Konami                       72.56
# Electronic Arts              66.26
# Polyphony Digital            65.20
# Namco                        63.11
# Neversoft Entertainment      61.27
# Vicarious Visions            56.98
# SquareSoft                   54.65
# Square Enix                  52.15
# Name: Global_Sales, dtype: float64

# %%
#23.Plot the bar chart for the above top 20 developers.
plt.figure(figsize=(12,6))
top_developers.plot(kind='bar', color='orange')
plt.xlabel('Developer')
plt.ylabel('Total Global Sales')
plt.title('Top 20 Developers by Global Sales')
plt.xticks(rotation=60)
plt.show()
